# %%
import pandas as pd
import numpy as np

# %%
titles = pd.read_csv('title.basics.tsv', sep='\t', na_values='\\N')

# %%
ratings = pd.read_csv('title.ratings.tsv', sep='\t', na_values='\\N')

# %%
df = titles[(titles['titleType'] == 'movie')]

# %%
df
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 331      tt0000335     movie
# 498      tt0000502     movie
# 570      tt0000574     movie
# 610      tt0000615     movie
# ...            ...       ...
# 7374872  tt9916622     movie
# 7374899  tt9916680     movie
# 7374911  tt9916706     movie
# 7374922  tt9916730     movie
# 7374933  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 331                                  Soldiers of the Cross
# 498                                               Bohemios
# 570                            The Story of the Kelly Gang
# 610                                     Robbery Under Arms
# ...                                                    ...
# 7374872        Rodolpho Teóphilo - O Legado de um Pioneiro
# 7374899  De la ilusión al desconcierto: cine colombiano...
# 7374911                                    Dankyavar Danka
# ...

# %%
df.drop(columns=['titleType', 'endYear'])
# Out:
#             tconst                                       primaryTitle  \
# 8        tt0000009                                         Miss Jerry
# 331      tt0000335                              Soldiers of the Cross
# 498      tt0000502                                           Bohemios
# 570      tt0000574                        The Story of the Kelly Gang
# 610      tt0000615                                 Robbery Under Arms
# ...            ...                                                ...
# 7374872  tt9916622        Rodolpho Teóphilo - O Legado de um Pioneiro
# 7374899  tt9916680  De la ilusión al desconcierto: cine colombiano...
# 7374911  tt9916706                                    Dankyavar Danka
# 7374922  tt9916730                                             6 Gunn
# 7374933  tt9916754                     Chico Albuquerque - Revelações
#
#                                              originalTitle  isAdult  \
# ...

# %%
df.set_index('tconst', inplace=True)

# %%
df
# Out:
#           titleType                                       primaryTitle  \
# tconst
# tt0000009     movie                                         Miss Jerry
# tt0000335     movie                              Soldiers of the Cross
# tt0000502     movie                                           Bohemios
# tt0000574     movie                        The Story of the Kelly Gang
# tt0000615     movie                                 Robbery Under Arms
# ...             ...                                                ...
# tt9916622     movie        Rodolpho Teóphilo - O Legado de um Pioneiro
# tt9916680     movie  De la ilusión al desconcierto: cine colombiano...
# tt9916706     movie                                    Dankyavar Danka
# tt9916730     movie                                             6 Gunn
# tt9916754     movie                     Chico Albuquerque - Revelações
#
#                                                originalTitle  isAdult  \
# tconst
# ...

# %%
ratings.set_index('tconst', inplace=True)

# %%
ratings
# Out:
#            averageRating  numVotes
# tconst
# tt0000001            5.6      1665
# tt0000002            6.1       205
# tt0000003            6.5      1382
# tt0000004            6.2       123
# tt0000005            6.2      2168
# ...                  ...       ...
# tt9916580            7.2         5
# tt9916690            6.6         5
# tt9916720            6.0        67
# tt9916766            6.9        15
# tt9916778            7.3        24
#
# [1096001 rows x 2 columns]

# %%
df.merge(ratings, left_on='tconst', right_on='tconst', how='left')
# Out:
#           titleType                                       primaryTitle  \
# tconst
# tt0000009     movie                                         Miss Jerry
# tt0000335     movie                              Soldiers of the Cross
# tt0000502     movie                                           Bohemios
# tt0000574     movie                        The Story of the Kelly Gang
# tt0000615     movie                                 Robbery Under Arms
# ...             ...                                                ...
# tt9916622     movie        Rodolpho Teóphilo - O Legado de um Pioneiro
# tt9916680     movie  De la ilusión al desconcierto: cine colombiano...
# tt9916706     movie                                    Dankyavar Danka
# tt9916730     movie                                             6 Gunn
# tt9916754     movie                     Chico Albuquerque - Revelações
#
#                                                originalTitle  isAdult  \
# tconst
# ...

# %%
df['startYear'].value_counts()
# Out:
# 2017.0    17636
# 2016.0    17334
# 2018.0    17331
# 2019.0    16458
# 2015.0    16215
#           ...
# 2025.0        3
# 2026.0        3
# 1897.0        1
# 2028.0        1
# 1894.0        1
# Name: startYear, Length: 133, dtype: int64
